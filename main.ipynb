# %%
import pandas as pd

data = pd.read_csv('Data/2013/electionnepal13/Data/election result top 3 in 240 Constituencies .csv')
data.tail(5)
# data.columns

# data2 =
# Out:
#        District Constituencies              Winner1 Vote of Winner1  \
# 235  Dadeldhura    Dadeldhura-1    शेर बहादुर देउबा           २३९२०
# 236  Kanchanpur    Kanchanpur-1    दिवान सिंह विष्ट           १०२९४
# 237         NaN    Kanchanpur-2  नारायण प्रकाश साउद           १३४१५
# 238         NaN    Kanchanpur-3    बहादुर सिंह थापा           १२८३६
# 239         NaN    Kanchanpur-4           रमेश लेखक           १४०२३
#
#         Winner1 Name               Winner 2 Vote of Winner2  \
# 235  नेपाली काँग्रेस             खगराज भट्ट           १२४९३
# 236  नेपाली काँग्रेस  लाल बहादुर विश्वकर्मा            ९२३६
# 237  नेपाली काँग्रेस         तारा लामा तमाङ            ९६७६
# 238  नेपाली काँग्रेस         नर बहादुर धामी            ९६४३
# 239  नेपाली काँग्रेस              मोहन गिरी            ५४३७
#
#                                  Winner2 Name                Winner3  \
# 235  एकीकृत नेपाल कम्युनिष्ट पार्टी (माओवादी)       तारा प्रसाद जोशी
# ...
